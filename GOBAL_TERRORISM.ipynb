# %% [markdown]
# <a href="https://colab.research.google.com/github/nivethitha2001/SPARKS-FOUNDATION-INTERN/blob/main/GOBAL_TERRORISM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TASK - 3**
#
# ## **EXPLORATORY DATA ANALYSIS ON DATASET - TERRORISM**
#
# **DONE BY: NIVETHITHA.S**

# %% [markdown]
# ### **Importing all libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ### **Loading dataset**

# %%
data=pd.read_csv(r'/content/globalterrorism.csv',encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-597bd3601049> in <module>()
# ----> 1 data=pd.read_csv(r'/content/globalterrorism.csv',encoding="latin1")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# ### **Data Preprocessing**

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.corr()
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002706  ... -0.133252 -0.077852 -0.175605
# iyear      0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth     0.002706  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday       0.018336  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091761  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077852 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175605 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %%
data.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# 181690  201712310032   2017      12    31  ...       -9         0      -9      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### **Cleaning data**

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                       'region_txt':'Region','city':'City','latitude':'Latitude','longitude':'Longitude','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data=data[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
data.head()
# Out:
#    Year  Month  Day  ...                  Target_type Weapon_type Motive
# 0  1970      7    2  ...  Private Citizens & Property     Unknown    NaN
# 1  1970      0    0  ...      Government (Diplomatic)     Unknown    NaN
# 2  1970      1    0  ...          Journalists & Media     Unknown    NaN
# 3  1970      1    0  ...      Government (Diplomatic)  Explosives    NaN
# 4  1970      1    0  ...      Government (Diplomatic)  Incendiary    NaN
#
# [5 rows x 18 columns]

# %% [markdown]
# ### **Handling missing data**

# %%
data.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# State             421
# Region              0
# City              434
# Latitude         4556
# Longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap="viridis")

# %%
data['Wounded'] = data['Wounded'].fillna(0)
data['Killed'] = data['Killed'].fillna(0)
data['Casualities'] = data['Killed'] + data['Wounded']

# %%
data['State'].fillna("unknown", inplace = True)
data['City'].fillna("unknown", inplace = True)

# %%
data.dropna(axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# State          0
# Region         0
# City           0
# AttackType     0
# Killed         0
# Wounded        0
# Group          0
# Target_type    0
# Weapon_type    0
# Casualities    0
# dtype: int64

# %%
print("Most attack month:",data['Month'].value_counts().idxmax())
print("Most attack Year:",data['Year'].value_counts().idxmax())
print("Most attack City:",data['City'].value_counts().index[1])
print("Most attack Country",data['Country'].value_counts().idxmax())
print("Region with the most attacks:",data['Region'].value_counts().idxmax())
print("Group with the most attacks:",data['Group'].value_counts().index[1])
print("Most Attack Types:",data['AttackType'].value_counts().idxmax())
# Out:
# Most attack month: 5
# Most attack Year: 2014
# Most attack City: Baghdad
# Most attack Country Iraq
# Region with the most attacks: Middle East & North Africa
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %%
data['Year'].value_counts(dropna = False).sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %% [markdown]
# ### **Data Visualization**

# %%
plt.figure(figsize=[10,8])
sns.heatmap(data.corr(),cmap='Blues', linewidths=0.4,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.rcParams["figure.figsize"] = 15,11
sns.barplot(x = data["Country"].value_counts()[:20].index, y=data["Country"].value_counts()[:20].values)
plt.ylabel("Number of Attacks", size=20)
plt.xticks(rotation=90)
plt.xlabel("Country", size=20)
plt.title("COUNTRY WISE ATTACKS", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'COUNTRY WISE ATTACKS')

# %%
top_countries = data.Country.value_counts().head(20)
top_countries
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
plt.pie(top_countries, labels=top_countries.index)
plt.title("Top 20 Countries with most terror attack")
plt.show()

# %%
pd.crosstab(data.Year, data.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.ylabel('Numbers of Attacks',size=20)
plt.xlabel("Year of attack",size=20)
plt.title('TERRORIST ACTIVITIES BY REGION',size=25,fontweight="bold")
plt.show()

# %%
plt.rcParams["figure.figsize"] = 20,10
sns.barplot(x = data["Month"].value_counts()[:20].index, y=data["Month"].value_counts()[:20].values)
plt.ylabel("Number of Attacks", size=18)
plt.xticks(rotation=90)
plt.xlabel("Month of Attack", size=20)
plt.title(" ATTACKS BY MONTH ", size=25, fontweight="bold")
plt.show()

# %%
year = data['Year'].unique()
years_count = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,y = years_count,palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('Year',size=20)
plt.ylabel('Number of Attacks',size=20)
plt.title('NUMBER OF ATTACKS YEAR WISE',size=25,fontweight="bold")
plt.show()

# %%
df = data[['Year','Killed']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.ylabel("Number of people killed",size=20)
plt.xlabel('Year',fontsize=20)
plt.title("PEOPLE DIED IN ATTACK",size=25,fontweight="bold")
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
plt.rcParams["figure.figsize"] = 20, 8
sns.barplot(x = data["Group"].value_counts()[:20].index, y=data["Group"].value_counts()[:20].values)
plt.ylabel("Total Attack", size=20)
plt.xticks(rotation=90)
plt.xlabel("Attack Group", size=20)
plt.title("ATTACKS BY GROUP", size=25, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'ATTACKS BY GROUP')

# %%
data['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color=(0.2, 0.7, 0.3, 0.8))
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=20)
plt.ylabel("Number of attack",fontsize=20)
plt.title("TOP 10 MOST EFFECTED CITIES",size=25,fontweight="bold")
plt.show()

# %%
data[['AttackType','Killed']].groupby(["AttackType"],axis=0).sum().plot(kind='bar',figsize=(20,8),color=(0.1, 0.5, 0.4, 0.9))
plt.xticks(rotation=50)
plt.ylabel('Number of people killed',fontsize=20)
plt.xlabel('Attack type',fontsize=20)
plt.title("NUMBER OF PEOPLE KILLED IN DIFFERENT ATTACK TYPES",fontsize=25,fontweight="bold")
plt.show()

# %%
df=data[['Country','Group','Killed']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('Killed',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-403a48da3e80> in <module>()
# ----> 1 df=data[['Country','Group','Killed']]
#       2 df=df.groupby(['Group','Country'],axis=0).sum().sort_values('Killed',ascending=False).drop('Unknown').reset_index().head(10)
#       3 df
#
# NameError: name 'data' is not defined
